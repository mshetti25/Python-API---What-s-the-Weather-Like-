# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("""-----------------------------
Beginning Data Retrieval      
-----------------------------""")
def set_func(cities, set_size):
    for i in range(0, len(cities), set_size):
        yield cities[i: i + set_size]

set_size = 50
city_sets = set_func(cities, set_size)

def weather_func(city):
    url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = f"{url}appid={weather_api_key}&q={city}"
    response = requests.get(query_url).json()
    return response

def city_func(cities):    
    number = 1
    city_weather = []
    for c in city_sets:
        r = 1
        for city_name in c:
            data = weather_func(city_name)
            data
            # include format string into it along with try catch if city is not found
            if data['cod'] == 200:
                print(f'Processing Record {r} of Set {number} | {city_name}')
                # Save data into another list
                city_lat = data["coord"]["lat"]
                city_lng = data["coord"]["lon"]
                city_cloud = data["clouds"]["all"]
                city_temp_max = data["main"]["temp_max"]
                city_humid = data["main"]["humidity"]
                city_wind = data["wind"]["speed"]
                city_country = data["sys"]["country"]
                city_date = data["dt"]
                city_weather.append({"City": city_name,
                                     "Lat" : city_lat,
                                     "Lng" : city_lng,
                                     "Max Temp" : city_temp_max,
                                     "Humidity" : city_humid,
                                     "Cloudiness" : city_cloud,
                                     "Wind Speed" : city_wind,
                                     "Country" : city_country,
                                     "Date" : city_date}) 
                
                
                r += 1
            else:             
                print('City not found. Skipping...')
        number += 1
    return city_weather

Final = city_func(city_sets)
print("""-----------------------------
Data Retrieval Complete      
-----------------------------""")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 | bukachacha
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | banda aceh
# City not found. Skipping...
# Processing Record 5 of Set 1 | sompeta
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | ulladulla
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | wattegama
# Processing Record 13 of Set 1 | seymchan
# Processing Record 14 of Set 1 | araouane
# Processing Record 15 of Set 1 | makakilo city
# Processing Record 16 of Set 1 | geraldton
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | samarai
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | raga
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | novikovo
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | talen
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | zhigansk
# Processing Record 31 of Set 1 | matara
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | sao felix do xingu
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | nhamunda
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | okhotsk
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | petrov val
# Processing Record 42 of Set 1 | anchorage
# Processing Record 43 of Set 1 | orcopampa
# Processing Record 44 of Set 1 | filingue
# Processing Record 45 of Set 1 | poncitlan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 1 of Set 2 | vokhtoga
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | verkhnyaya sinyachikha
# Processing Record 4 of Set 2 | haines junction
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | rocha
# Processing Record 7 of Set 2 | yerbogachen
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | camocim
# Processing Record 10 of Set 2 | saint-augustin
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | nome
# Processing Record 13 of Set 2 | tateyama
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | toamasina
# Processing Record 17 of Set 2 | calderitas
# Processing Record 18 of Set 2 | takoradi
# Processing Record 19 of Set 2 | buraydah
# City not found. Skipping...
# Processing Record 20 of Set 2 | mangan
# Processing Record 21 of Set 2 | garissa
# City not found. Skipping...
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | virar
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | buckeye
# Processing Record 26 of Set 2 | mikkeli
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | ada
# Processing Record 33 of Set 2 | farafangana
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | mingguang
# Processing Record 39 of Set 2 | flinders
# Processing Record 40 of Set 2 | puerto madryn
# Processing Record 41 of Set 2 | maragogi
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | general roca
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | muzhi
# Processing Record 3 of Set 3 | tezu
# Processing Record 4 of Set 3 | harboore
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | sao joao da barra
# Processing Record 7 of Set 3 | hurricane
# Processing Record 8 of Set 3 | mawlaik
# Processing Record 9 of Set 3 | saint anthony
# Processing Record 10 of Set 3 | grindavik
# City not found. Skipping...
# Processing Record 11 of Set 3 | obeliai
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | zlobin
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | aklavik
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | belaya gora
# City not found. Skipping...
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | chilca
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | inhambane
# Processing Record 23 of Set 3 | tiznit
# Processing Record 24 of Set 3 | flin flon
# Processing Record 25 of Set 3 | chizhou
# Processing Record 26 of Set 3 | khani
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | puerto del rosario
# City not found. Skipping...
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | gigmoto
# City not found. Skipping...
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | pelym
# Processing Record 33 of Set 3 | lagoa da prata
# Processing Record 34 of Set 3 | harfleur
# Processing Record 35 of Set 3 | pierre
# Processing Record 36 of Set 3 | lakatoro
# Processing Record 37 of Set 3 | havre-saint-pierre
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | dukat
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | hearst
# Processing Record 42 of Set 3 | clarence town
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | kutum
# City not found. Skipping...
# Processing Record 45 of Set 3 | gat
# Processing Record 1 of Set 4 | jalu
# Processing Record 2 of Set 4 | aswan
# Processing Record 3 of Set 4 | mogadishu
# City not found. Skipping...
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | port-gentil
# City not found. Skipping...
# Processing Record 6 of Set 4 | grajau
# Processing Record 7 of Set 4 | gamba
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | giyon
# Processing Record 11 of Set 4 | khandyga
# Processing Record 12 of Set 4 | adrar
# Processing Record 13 of Set 4 | eureka
# Processing Record 14 of Set 4 | kalabo
# Processing Record 15 of Set 4 | laibin
# Processing Record 16 of Set 4 | dafeng
# Processing Record 17 of Set 4 | altay
# Processing Record 18 of Set 4 | jaen
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | lemoore
# City not found. Skipping...
# Processing Record 22 of Set 4 | chaohu
# Processing Record 23 of Set 4 | zhigalovo
# Processing Record 24 of Set 4 | chipata
# City not found. Skipping...
# Processing Record 25 of Set 4 | poum
# Processing Record 26 of Set 4 | zubtsov
# Processing Record 27 of Set 4 | mbandaka
# Processing Record 28 of Set 4 | rio gallegos
# Processing Record 29 of Set 4 | touros
# City not found. Skipping...
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | kailua
# Processing Record 32 of Set 4 | muisne
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | pacific grove
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | waipawa
# Processing Record 39 of Set 4 | chuy
# Processing Record 40 of Set 4 | bethel
# Processing Record 41 of Set 4 | soe
# Processing Record 42 of Set 4 | padang
# Processing Record 43 of Set 4 | lompoc
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | lasa
# Processing Record 1 of Set 5 | ostrovnoy
# Processing Record 2 of Set 5 | tabuk
# Processing Record 3 of Set 5 | camopi
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | lima
# Processing Record 6 of Set 5 | jumla
# City not found. Skipping...
# Processing Record 7 of Set 5 | khakhea
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | martapura
# Processing Record 10 of Set 5 | puttur
# Processing Record 11 of Set 5 | coihaique
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | horizontina
# Processing Record 14 of Set 5 | neyshabur
# Processing Record 15 of Set 5 | hilton head island
# Processing Record 16 of Set 5 | bairnsdale
# Processing Record 17 of Set 5 | port lincoln
# Processing Record 18 of Set 5 | kars
# Processing Record 19 of Set 5 | nassjo
# Processing Record 20 of Set 5 | grand bank
# Processing Record 21 of Set 5 | dhekiajuli
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | bayanday
# Processing Record 24 of Set 5 | miloslavskoye
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | bisira
# City not found. Skipping...
# Processing Record 27 of Set 5 | farrukhnagar
# Processing Record 28 of Set 5 | skibbereen
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | freeport
# City not found. Skipping...
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | sept-iles
# Processing Record 33 of Set 5 | labuan
# Processing Record 34 of Set 5 | sihora
# Processing Record 35 of Set 5 | bairiki
# Processing Record 36 of Set 5 | tagusao
# Processing Record 37 of Set 5 | kem
# Processing Record 38 of Set 5 | datong
# Processing Record 39 of Set 5 | kamaishi
# Processing Record 40 of Set 5 | etchojoa
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | belmonte
# City not found. Skipping...
# Processing Record 43 of Set 5 | ylivieska
# Processing Record 44 of Set 5 | tjome
# Processing Record 45 of Set 5 | nanning
# Processing Record 46 of Set 5 | airai
# Processing Record 1 of Set 6 | yaroslavskiy
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | luwingu
# City not found. Skipping...
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | verkhnevilyuysk
# Processing Record 6 of Set 6 | duldurga
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | mapiripan
# Processing Record 9 of Set 6 | itarema
# Processing Record 10 of Set 6 | barrow
# Processing Record 11 of Set 6 | monte san giovanni campano
# Processing Record 12 of Set 6 | beaumont
# Processing Record 13 of Set 6 | roma
# Processing Record 14 of Set 6 | bilma
# Processing Record 15 of Set 6 | antalaha
# Processing Record 16 of Set 6 | shaunavon
# Processing Record 17 of Set 6 | novolabinskaya
# Processing Record 18 of Set 6 | kandrian
# Processing Record 19 of Set 6 | cap malheureux
# Processing Record 20 of Set 6 | strelka
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | hargeysa
# Processing Record 23 of Set 6 | nantucket
# Processing Record 24 of Set 6 | villa florida
# Processing Record 25 of Set 6 | rockhampton
# Processing Record 26 of Set 6 | namie
# Processing Record 27 of Set 6 | port blair
# Processing Record 28 of Set 6 | husavik
# Processing Record 29 of Set 6 | altamira
# Processing Record 30 of Set 6 | bathsheba
# Processing Record 31 of Set 6 | udachnyy
# Processing Record 32 of Set 6 | saint george
# Processing Record 33 of Set 6 | sawakin
# Processing Record 34 of Set 6 | kashmor
# Processing Record 35 of Set 6 | cherskiy
# Processing Record 36 of Set 6 | xiaoshan
# Processing Record 37 of Set 6 | baghdad
# Processing Record 38 of Set 6 | urla
# Processing Record 39 of Set 6 | nanae
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | kalmunai
# Processing Record 42 of Set 6 | nsanje
# Processing Record 43 of Set 6 | avera
# Processing Record 44 of Set 6 | saint-ambroise
# Processing Record 45 of Set 6 | los llanos de aridane
# Processing Record 46 of Set 6 | bom jesus
# Processing Record 47 of Set 6 | liancheng
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | ancud
# Processing Record 1 of Set 7 | berlevag
# Processing Record 2 of Set 7 | comodoro rivadavia
# Processing Record 3 of Set 7 | verkhoyansk
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | caluquembe
# Processing Record 6 of Set 7 | asyut
# Processing Record 7 of Set 7 | annau
# Processing Record 8 of Set 7 | trairi
# Processing Record 9 of Set 7 | mezen
# Processing Record 10 of Set 7 | atar
# Processing Record 11 of Set 7 | sao jose da coroa grande
# Processing Record 12 of Set 7 | quatre cocos
# Processing Record 13 of Set 7 | buala
# Processing Record 14 of Set 7 | biak
# City not found. Skipping...
# Processing Record 15 of Set 7 | udalguri
# Processing Record 16 of Set 7 | devli
# Processing Record 17 of Set 7 | vardo
# Processing Record 18 of Set 7 | ahipara
# Processing Record 19 of Set 7 | kavieng
# Processing Record 20 of Set 7 | leshukonskoye
# Processing Record 21 of Set 7 | fatezh
# Processing Record 22 of Set 7 | namibe
# Processing Record 23 of Set 7 | yermakovskoye
# Processing Record 24 of Set 7 | san cristobal
# Processing Record 25 of Set 7 | lebu
# Processing Record 26 of Set 7 | fort nelson
# Processing Record 27 of Set 7 | luanda
# Processing Record 28 of Set 7 | luwuk
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | sechura
# Processing Record 31 of Set 7 | antofagasta
# Processing Record 32 of Set 7 | vostok
# Processing Record 33 of Set 7 | broken hill
# Processing Record 34 of Set 7 | pocos de caldas
# Processing Record 35 of Set 7 | carutapera
# Processing Record 36 of Set 7 | peterhead
# Processing Record 37 of Set 7 | nakamura
# Processing Record 38 of Set 7 | viedma
# Processing Record 39 of Set 7 | awjilah
# Processing Record 40 of Set 7 | andenes
# Processing Record 41 of Set 7 | conway
# Processing Record 42 of Set 7 | beringovskiy
# Processing Record 43 of Set 7 | saint-philippe
# Processing Record 44 of Set 7 | taoudenni
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | channel-port aux basques
# Processing Record 47 of Set 7 | daru
# City not found. Skipping...
# Processing Record 48 of Set 7 | rochegda
# Processing Record 1 of Set 8 | tornio
# Processing Record 2 of Set 8 | nyurba
# Processing Record 3 of Set 8 | jiayuguan
# Processing Record 4 of Set 8 | sembakung
# City not found. Skipping...
# Processing Record 5 of Set 8 | coolum beach
# Processing Record 6 of Set 8 | ixtapa
# Processing Record 7 of Set 8 | broome
# Processing Record 8 of Set 8 | esperance
# Processing Record 9 of Set 8 | maceio
# Processing Record 10 of Set 8 | suicheng
# Processing Record 11 of Set 8 | beyneu
# Processing Record 12 of Set 8 | gao
# Processing Record 13 of Set 8 | rawson
# Processing Record 14 of Set 8 | vanimo
# Processing Record 15 of Set 8 | shingu
# Processing Record 16 of Set 8 | trelew
# Processing Record 17 of Set 8 | palu
# Processing Record 18 of Set 8 | acari
# Processing Record 19 of Set 8 | abu zabad
# Processing Record 20 of Set 8 | tura
# Processing Record 21 of Set 8 | olinda
# Processing Record 22 of Set 8 | dawlatabad
# Processing Record 23 of Set 8 | fulton
# Processing Record 24 of Set 8 | paamiut
# Processing Record 25 of Set 8 | pendleton
# Processing Record 26 of Set 8 | torbay
# Processing Record 27 of Set 8 | hualmay
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | nuevo imperial
# Processing Record 30 of Set 8 | lianzhou
# Processing Record 31 of Set 8 | port hedland
# Processing Record 32 of Set 8 | cooma
# Processing Record 33 of Set 8 | thinadhoo
# City not found. Skipping...
# Processing Record 34 of Set 8 | kemijarvi
# Processing Record 35 of Set 8 | bella vista
# Processing Record 36 of Set 8 | gravdal
# Processing Record 37 of Set 8 | cascais
# Processing Record 38 of Set 8 | marand
# Processing Record 39 of Set 8 | sattahip
# Processing Record 40 of Set 8 | wanning
# Processing Record 41 of Set 8 | fairbanks
# Processing Record 42 of Set 8 | churachandpur
# Processing Record 43 of Set 8 | nouakchott
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | gorom-gorom
# Processing Record 46 of Set 8 | luderitz
# Processing Record 47 of Set 8 | kastamonu
# Processing Record 48 of Set 8 | bajil
# Processing Record 1 of Set 9 | anadyr
# Processing Record 2 of Set 9 | kahului
# Processing Record 3 of Set 9 | yarmouth
# Processing Record 4 of Set 9 | lethem
# City not found. Skipping...
# Processing Record 5 of Set 9 | kodinsk
# Processing Record 6 of Set 9 | bjornevatn
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | the valley
# Processing Record 9 of Set 9 | hami
# Processing Record 10 of Set 9 | riyadh
# Processing Record 11 of Set 9 | madisonville
# Processing Record 12 of Set 9 | santa cruz
# Processing Record 13 of Set 9 | bontang
# Processing Record 14 of Set 9 | bundaberg
# City not found. Skipping...
# Processing Record 15 of Set 9 | hambantota
# Processing Record 16 of Set 9 | socuellamos
# City not found. Skipping...
# Processing Record 17 of Set 9 | revda
# Processing Record 18 of Set 9 | kakching
# Processing Record 19 of Set 9 | reconquista
# Processing Record 20 of Set 9 | bereda
# Processing Record 21 of Set 9 | ewo
# Processing Record 22 of Set 9 | lumberton
# Processing Record 23 of Set 9 | monroe
# Processing Record 24 of Set 9 | san felipe
# Processing Record 25 of Set 9 | fare
# Processing Record 26 of Set 9 | angoche
# Processing Record 27 of Set 9 | emba
# Processing Record 28 of Set 9 | saint-joseph
# Processing Record 29 of Set 9 | nador
# Processing Record 30 of Set 9 | sobolevo
# City not found. Skipping...
# Processing Record 31 of Set 9 | rorvik
# Processing Record 32 of Set 9 | xapuri
# Processing Record 33 of Set 9 | tartagal
# Processing Record 34 of Set 9 | moose factory
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | grand-santi
# Processing Record 37 of Set 9 | sola
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | ushtobe
# Processing Record 40 of Set 9 | deputatskiy
# Processing Record 41 of Set 9 | birjand
# Processing Record 42 of Set 9 | guerrero negro
# Processing Record 43 of Set 9 | sambava
# Processing Record 44 of Set 9 | itaperuna
# Processing Record 45 of Set 9 | nouadhibou
# Processing Record 46 of Set 9 | liuzhou
# Processing Record 1 of Set 10 | carauari
# City not found. Skipping...
# Processing Record 2 of Set 10 | chara
# Processing Record 3 of Set 10 | diglur
# Processing Record 4 of Set 10 | laguna
# Processing Record 5 of Set 10 | hovd
# Processing Record 6 of Set 10 | gobabis
# Processing Record 7 of Set 10 | yaya
# Processing Record 8 of Set 10 | westport
# City not found. Skipping...
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | mount gambier
# Processing Record 11 of Set 10 | richards bay
# City not found. Skipping...
# Processing Record 12 of Set 10 | baruun-urt
# Processing Record 13 of Set 10 | alofi
# Processing Record 14 of Set 10 | chapais
# Processing Record 15 of Set 10 | kati
# Processing Record 16 of Set 10 | kimbe
# City not found. Skipping...
# Processing Record 17 of Set 10 | brigantine
# Processing Record 18 of Set 10 | kigoma
# Processing Record 19 of Set 10 | maumere
# Processing Record 20 of Set 10 | belogorsk
# Processing Record 21 of Set 10 | ambon
# Processing Record 22 of Set 10 | tocopilla
# Processing Record 23 of Set 10 | saint-felicien
# Processing Record 24 of Set 10 | oranjemund
# City not found. Skipping...
# Processing Record 25 of Set 10 | mormugao
# Processing Record 26 of Set 10 | sanchez
# City not found. Skipping...
# Processing Record 27 of Set 10 | inirida
# Processing Record 28 of Set 10 | bud
# City not found. Skipping...
# Processing Record 29 of Set 10 | kismayo
# Processing Record 30 of Set 10 | lashio
# Processing Record 31 of Set 10 | constitucion
# Processing Record 32 of Set 10 | khanpur
# Processing Record 33 of Set 10 | wonthaggi
# City not found. Skipping...
# Processing Record 34 of Set 10 | san quintin
# Processing Record 35 of Set 10 | anshun
# Processing Record 36 of Set 10 | alekseyevsk
# Processing Record 37 of Set 10 | muslyumovo
# City not found. Skipping...
# Processing Record 38 of Set 10 | opatija
# Processing Record 39 of Set 10 | barra
# Processing Record 40 of Set 10 | camacha
# Processing Record 41 of Set 10 | margate
# Processing Record 1 of Set 11 | potosi
# Processing Record 2 of Set 11 | dondo
# Processing Record 3 of Set 11 | mahibadhoo
# Processing Record 4 of Set 11 | ambatondrazaka
# Processing Record 5 of Set 11 | nigde
# City not found. Skipping...
# Processing Record 6 of Set 11 | bar harbor
# Processing Record 7 of Set 11 | pisco
# Processing Record 8 of Set 11 | dogondoutchi
# Processing Record 9 of Set 11 | iguape
# Processing Record 10 of Set 11 | sinnamary
# Processing Record 11 of Set 11 | seguin
# Processing Record 12 of Set 11 | acarau
# Processing Record 13 of Set 11 | teknaf
# Processing Record 14 of Set 11 | yar-sale
# Processing Record 15 of Set 11 | srandakan
# Processing Record 16 of Set 11 | maniitsoq
# Processing Record 17 of Set 11 | ponta delgada
# Processing Record 18 of Set 11 | lesnoy
# Processing Record 19 of Set 11 | oudtshoorn
# Processing Record 20 of Set 11 | san andres
# Processing Record 21 of Set 11 | praia
# Processing Record 22 of Set 11 | naushki
# Processing Record 23 of Set 11 | ramgarh
# Processing Record 24 of Set 11 | tungor
# Processing Record 25 of Set 11 | santa rosa
# Processing Record 26 of Set 11 | okha
# Processing Record 27 of Set 11 | marawi
# Processing Record 28 of Set 11 | mayo
# Processing Record 29 of Set 11 | kresttsy
# Processing Record 30 of Set 11 | banepa
# Processing Record 31 of Set 11 | vila franca do campo
# Processing Record 32 of Set 11 | progreso
# Processing Record 33 of Set 11 | valparaiso
# Processing Record 34 of Set 11 | pyay
# Processing Record 35 of Set 11 | solnechnyy
# Processing Record 36 of Set 11 | lerwick
# Processing Record 37 of Set 11 | baikunthpur
# Processing Record 38 of Set 11 | northam
# Processing Record 39 of Set 11 | homestead
# Processing Record 40 of Set 11 | atambua
# Processing Record 41 of Set 11 | red deer
# Processing Record 42 of Set 11 | bonfim
# Processing Record 43 of Set 11 | vao
# Processing Record 44 of Set 11 | tiffin
# Processing Record 45 of Set 11 | sur
# Processing Record 46 of Set 11 | dolores
# Processing Record 47 of Set 11 | tual
# Processing Record 48 of Set 11 | xining
# Processing Record 49 of Set 11 | fortuna
# Processing Record 1 of Set 12 | naifaru
# Processing Record 2 of Set 12 | sandnessjoen
# Processing Record 3 of Set 12 | buchanan
# Processing Record 4 of Set 12 | trincomalee
# Processing Record 5 of Set 12 | itapirapua
# Processing Record 6 of Set 12 | isangel
# Processing Record 7 of Set 12 | manjacaze
# Processing Record 8 of Set 12 | seoul
# Processing Record 9 of Set 12 | kongolo
# Processing Record 10 of Set 12 | shache
# Processing Record 11 of Set 12 | finsterwalde
# Processing Record 12 of Set 12 | opuwo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 12 | salinas
# Processing Record 14 of Set 12 | tsaratanana
# Processing Record 15 of Set 12 | camp verde
# Processing Record 16 of Set 12 | darhan
# City not found. Skipping...
# Processing Record 17 of Set 12 | muros
# Processing Record 18 of Set 12 | grakhovo
# Processing Record 19 of Set 12 | ust-nera
# Processing Record 20 of Set 12 | oktyabrskoye
# Processing Record 21 of Set 12 | borovskoy
# Processing Record 22 of Set 12 | gonbad-e qabus
# Processing Record 23 of Set 12 | ihosy
# Processing Record 24 of Set 12 | palana
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | esna
# Processing Record 27 of Set 12 | santa rita
# Processing Record 28 of Set 12 | nipawin
# Processing Record 29 of Set 12 | hirara
# Processing Record 30 of Set 12 | north bend
# Processing Record 31 of Set 12 | aasiaat
# Processing Record 32 of Set 12 | redding
# Processing Record 33 of Set 12 | sitka
# Processing Record 34 of Set 12 | todos santos
# Processing Record 35 of Set 12 | aberdeen
# Processing Record 36 of Set 12 | kaka
# Processing Record 37 of Set 12 | adre
# City not found. Skipping...
# Processing Record 38 of Set 12 | great bend
# Processing Record 39 of Set 12 | honiara
# Processing Record 40 of Set 12 | matagami
# Processing Record 41 of Set 12 | monteagudo
# Processing Record 42 of Set 12 | teya
# Processing Record 43 of Set 12 | nixa
# Processing Record 44 of Set 12 | dawei
# Processing Record 45 of Set 12 | vila
# Processing Record 46 of Set 12 | matay
# Processing Record 1 of Set 13 | montefiascone
# Processing Record 2 of Set 13 | tambun
# City not found. Skipping...
# Processing Record 3 of Set 13 | kargasok
# Processing Record 4 of Set 13 | namatanai
# Processing Record 5 of Set 13 | ostersund
# Processing Record 6 of Set 13 | north platte
# Processing Record 7 of Set 13 | yei
# Processing Record 8 of Set 13 | sisimiut
# Processing Record 9 of Set 13 | yerofey pavlovich
# Processing Record 10 of Set 13 | arenapolis
# Processing Record 11 of Set 13 | concepcion del oro
# Processing Record 12 of Set 13 | rio grande
# Processing Record 13 of Set 13 | vichy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_df = pd.DataFrame(Final)
city_weather_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_weather_df.loc[city_weather_df["Humidity"] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
city_weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  569.000000
# mean    20.197276   18.720018  293.986661   70.943761   52.630931    3.438014
# std     33.090388   89.313556    7.597481   20.022443   37.874805    2.271860
# min    -54.800000 -175.200000  266.150000   10.000000    0.000000    0.100000
# 25%     -7.940000  -59.950000  288.100000   59.000000   14.000000    1.710000
# 50%     24.050000   25.570000  294.960000   76.000000   63.000000    3.000000
# 75%     47.870000   95.220000  299.150000   87.000000   90.000000    4.600000
# max     77.480000  179.320000  314.150000  100.000000  100.000000   12.990000
#
#                Date
# count  5.690000e+02
# mean   1.595288e+09
# std    9.240793e+01
# min    1.595288e+09
# 25%    1.595288e+09
# 50%    1.595288e+09
# 75%    1.595288e+09
# max    1.595288e+09

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame
City_Data = city_weather_df

# Export the City_Data into a csv
City_Data.to_csv (r'../output_data/City_Data.csv', index = False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_weather_df["Lat"],city_weather_df["Max Temp"] , marker="o", facecolors="blue", edgecolors="black",
            alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude v/s Max Temperature(07/15/2020)")
plt.grid()
plt.savefig('../output_data/Lat_Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather_df["Lat"],city_weather_df["Max Temp"]  , marker="o", facecolors="turquoise", edgecolors="black",
            alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude v/s Humidity(07/15/2020)")
plt.savefig('../output_data/Lat_Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_weather_df["Lat"],city_weather_df["Cloudiness"]  , marker="o", facecolors="red", edgecolors="black",
            alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("City Latitude v/s Cloudiness(07/15/2020)")
plt.savefig('../output_data/Lat_Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_weather_df["Lat"],city_weather_df["Wind Speed"]  , marker="o", facecolors="green", edgecolors="black",
            alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title("City Latitude v/s Wind Speed(07/15/2020)")
plt.ylim([0,15])
plt.savefig('../output_data/Lat_Wind Speed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_df = City_Data.loc[city_weather_df["Lat"] >= 0]
Northern_df

Southern_df = City_Data.loc[city_weather_df["Lat"] < 0]
Southern_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1    puerto ayora  -0.74  -90.35    294.26        85          94        2.68
# 5           vaini -21.20 -175.20    297.15        64           0        3.60
# 6        hermanus -34.42   19.23    285.93        70           1        0.89
# 7       cape town -33.93   18.42    283.15        93           0        2.10
# 8       ulladulla -35.35  150.47    284.26        53           1        4.10
# ..            ...    ...     ...       ...       ...         ...         ...
# 550    monteagudo -19.82  -63.98    291.95        72          73        0.35
# 557        tambun  -6.26  107.07    298.15        94          20        1.42
# 559     namatanai  -3.67  152.43    302.57        67          25        2.17
# 565    arenapolis -14.45  -56.85    297.35        41          27        1.91
# 567    rio grande -32.03  -52.10    293.71        76          96        3.59
#
#     Country        Date
# 1        EC  1595287989
# 5        TO  1595287913
# 6        ZA  1595288106
# 7        ZA  1595287661
# 8        AU  1595288147
# ..      ...         ...
# 550      BO  1595288200
# 557      ID  1595288201
# 559      PG  1595288201
# 565      BR  1595288119
# 567      BR  1595287941
#
# [179 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,280),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Northern_MaxTemp_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.4262675175963572

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,300),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Southern_MaxTemp_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.6318378129166698

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Northern_Humidity_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.001189429270647436

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Southern_Humidity_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.02175417670614673

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Northern Hemisphere - Cloudiness vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Northern_Cloudiness_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.002291020303921336

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Southern Hemisphere - Cloudiness vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Southern_Cloudiness_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.01986540901171813

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,11),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Northern Hemisphere - Wind Speed vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Northern_Wind_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.012121138406856701

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')
plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('../output_data/Southern_Cloudiness_Lat.png')
plt.show()
# Out:
# The r-squared is: 0.000290033711947196

# %% [markdown]
# ## Analysis
# #### 1) There is strong correlation between latitude and temperature.
# #### 2) There is almost no correlation between cloudiness and latitude.
# #### 3) The higher latitudes have lower temperatures and the lower latitudes have higher temperatures.
# #### 4) The correlation between latitude and wind speed is very weak.
# #### 5)The correlation between humidity and latitude is very weak.
